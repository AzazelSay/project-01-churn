# %%
import sys
import pandas as pd

print(sys.executable)
print(pd.__version__)
# Out:
# c:\Users\AZAT\Desktop\AI-Learning\project-01-churn\.venv\Scripts\python.exe
# 2.2.3

# %%
# Kernel — это Python-процесс, который исполняет ячейки notebook.
# Очень важно, чтобы kernel был от твоего проекта, а не какой-то случайный глобальный Python.
